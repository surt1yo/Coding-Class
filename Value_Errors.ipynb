# %% [markdown]
# <a href="https://colab.research.google.com/github/surt1yo/Coding-Class/blob/main/Value_Errors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num=int(input("Enter a Number: "))
  print(num)
except ValueError as ex:
  print("Invalid Input")
print()
