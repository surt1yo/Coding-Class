# %% [markdown]
# <a href="https://colab.research.google.com/github/surt1yo/Coding-Class/blob/main/Current_date_and_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date,time,datetime
tday=date.today()
now=datetime.now()
print(f"Todays date is {tday}")
print(f"The time is {now.time()}.")
# Out:
# Todays date is 2025-11-07
# The time is 06:02:46.680735.
