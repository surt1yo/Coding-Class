# %% [markdown]
# <a href="https://colab.research.google.com/github/surt1yo/Coding-Class/blob/main/Infinity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i <= 0:
    print("mez")
# Out:
# Streaming output truncated to the last 5000 lines.
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# mez
# ...
